# %%
import pandas as pd

# Read dataset
df = pd.read_csv("leftover_donations.csv")

# Dataset info
df.info()

# First 5 rows
df.head()

# Missing values
df.isna().sum()

# Shape
df.shape

# Food type count
df["Food Type"].value_counts()

# Location count
df["Location"].value_counts()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Food Type    100 non-null    str
#  1   Title        100 non-null    str
#  2   Quantity     100 non-null    str
#  3   Location     100 non-null    str
#  4   Expiry       100 non-null    str
#  5   Description  100 non-null    str
# dtypes: str(6)
# memory usage: 12.5 KB
# Location
# Mumbai         10
# Thane          10
# Palghar        10
# Andheri        10
# Borivali       10
# Dadar          10
# Navi Mumbai    10
# Vasai          10
# Virar          10
# Pune           10
# Name: count, dtype: int64
